# %% [markdown]
# <a href="https://colab.research.google.com/github/NicolasBarrientosE/Finanzas_IA/blob/main/Solemne_Finanzas_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ejecuta esta celda SOLO si falta algo en tu Colab
# !pip -q install requests beautifulsoup4 lxml pandas pyarrow
